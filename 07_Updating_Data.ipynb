# %%
import pandas as pd

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sex.replace('female', 'F')
# Out:
# 0          F
# 1       male
# 2          F
# 3       male
# 4          F
#         ...
# 1304       F
# 1305       F
# 1306    male
# 1307    male
# 1308    male
# Name: sex, Length: 1309, dtype: object

# %%
titanic['sex'].replace(['female', 'male'], ['F', 'M'], inplace=True)
titanic
# Out:
# C:\Users\write\AppData\Local\Temp\ipykernel_28260\413284764.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['sex'].replace(['female', 'male'], ['F', 'M'], inplace=True)
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# ...

# %%
# When you want to replace something with None, use the list syntax even if you are only replacing one.

# %%
titanic['age'].replace(['?'], [None], inplace=True)
# Out:
# C:\Users\write\AppData\Local\Temp\ipykernel_28260\3065196104.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].replace(['?'], [None], inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton   F
# 1          1         1                   Allison, Master. Hudson Trevor   M
# 2          1         0                     Allison, Miss. Helen Loraine   F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton   M
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)   F
# ...      ...       ...                                              ...  ..
# 1304       3         0                             Zabour, Miss. Hileni   F
# 1305       3         0                            Zabour, Miss. Thamine   F
# 1306       3         0                        Zakarian, Mr. Mapriededer   M
# 1307       3         0                              Zakarian, Mr. Ortin   M
# 1308       3         0                               Zimmerman, Mr. Leo   M
#
# ...

# %%
titanic.age.value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
countries = pd.read_csv('data/world-happiness-report-2021.csv', index_col='Country name')
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc['Brazil': 'Cambodia']
# Out:
#                               Regional indicator  Ladder score  \
# Country name
# Brazil               Latin America and Caribbean         6.330
# Mexico               Latin America and Caribbean         6.317
# Jamaica              Latin America and Caribbean         6.309
# Lithuania             Central and Eastern Europe         6.255
# Cyprus                            Western Europe         6.223
# ...                                          ...           ...
# Ukraine       Commonwealth of Independent States         4.875
# Iraq                Middle East and North Africa         4.854
# Gabon                         Sub-Saharan Africa         4.852
# Burkina Faso                  Sub-Saharan Africa         4.834
# Cambodia                          Southeast Asia         4.830
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# ...

# %%
countries.loc['Brazil', ['Ladder score', 'Healthy life expectancy']]
# Out:
# Ladder score                 6.33
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
countries.loc[['Costa Rica', 'Panama', 'Honduras'], ['Ladder score', 'Healthy life expectancy']]
# Out:
#               Ladder score  Healthy life expectancy
# Country name
# Costa Rica           7.069                   71.400
# Panama               6.180                   69.652
# Honduras             5.919                   67.300

# %%
countries.loc[['Denmark', 'Sweden', 'Norway'], ['Regional indicator']]
# Out:
#              Regional indicator
# Country name
# Denmark          Western Europe
# Sweden           Western Europe
# Norway           Western Europe

# %%
countries.loc[['Denmark', 'Sweden', 'Norway'], ['Regional indicator']] = 'Scandinavia'
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark              Scandinavia         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc['Finland']
# Out:
# Regional indicator                            Western Europe
# Ladder score                                           7.842
# Standard error of ladder score                         0.032
# upperwhisker                                           7.904
# lowerwhisker                                            7.78
# Logged GDP per capita                                 10.775
# Social support                                         0.954
# Healthy life expectancy                                 72.0
# Freedom to make life choices                           0.949
# Generosity                                            -0.098
# Perceptions of corruption                              0.186
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.446
# Explained by: Social support                           1.106
# Explained by: Healthy life expectancy                  0.741
# ...

# %%
countries.loc[['Finland', 'Denmark', 'Iceland', 'Sweden', 'Norway']]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland          Western Europe         7.842                           0.032
# Denmark             Scandinavia         7.620                           0.035
# Iceland          Western Europe         7.554                           0.059
# Sweden              Scandinavia         7.363                           0.036
# Norway              Scandinavia         7.392                           0.035
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Iceland              7.670         7.438                 10.878
# Sweden               7.433         7.293                 10.867
# Norway               7.462         7.323                 11.053
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
countries.loc[['Finland', 'Denmark', 'Iceland', 'Sweden', 'Norway'], ['Regional indicator', 'is_cold']] = ['Nordic Countries', 'Yes']

# %%
countries.loc[['Finland', 'Denmark', 'Iceland', 'Sweden', 'Norway']]
# Out:
#              Regional indicator  Ladder score  Standard error of ladder score  \
# Country name
# Finland        Nordic Countries         7.842                           0.032
# Denmark        Nordic Countries         7.620                           0.035
# Iceland        Nordic Countries         7.554                           0.059
# Sweden         Nordic Countries         7.363                           0.036
# Norway         Nordic Countries         7.392                           0.035
#
#               upperwhisker  lowerwhisker  Logged GDP per capita  \
# Country name
# Finland              7.904         7.780                 10.775
# Denmark              7.687         7.552                 10.933
# Iceland              7.670         7.438                 10.878
# Sweden               7.433         7.293                 10.867
# Norway               7.462         7.323                 11.053
#
#               Social support  Healthy life expectancy  \
# Country name
# ...

# %%
houses = pd.read_csv('data/kc_house_data.csv')

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# # We can also use a boolean expresion with loc

# %%
many_bedrooms = houses['bedrooms'] >= 10

# %%
houses.loc[many_bedrooms, ['bedrooms']] = 'Too Many!'
houses[many_bedrooms]
# Out:
#                id             date      price   bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0  Too Many!       3.00
# 13314   627300145  20140814T000000  1148000.0  Too Many!       5.25
# 15161  5566100170  20141029T000000   650000.0  Too Many!       2.00
# 15870  2402100895  20140625T000000   640000.0  Too Many!       1.75
# 19254  8812401450  20141229T000000   660000.0  Too Many!       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
high_quality_houses = houses['grade'] > 12
good_view_houses = houses['view'] == 4
houses[good_view_houses & high_quality_houses]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 9254          9890     31374     2.0           0     4  ...     13
# 14556         8670     64033     2.0           0     4  ...     13
# 19017         5510     35000     2.0           0     4  ...     13
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 9254         8860           1030      2001             0    98039  47.6305
# 14556        6120           2550      1965          2003    98177  47.7295
# 19017        4910            600      1997             0    98177  47.7296
#
#           long  sqft_living15  sqft_lot15
# 9254  -122.240           4540       42730
# ...

# %%
houses['luxury_level'] = 'normal'

# %%
houses
# Out:
#                id             date     price bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000  221900.0        3       1.00         1180
# 1      6414100192  20141209T000000  538000.0        3       2.25         2570
# 2      5631500400  20150225T000000  180000.0        2       1.00          770
# 3      2487200875  20141209T000000  604000.0        4       3.00         1960
# 4      1954400510  20150218T000000  510000.0        3       2.00         1680
# ...           ...              ...       ...      ...        ...          ...
# 21608   263000018  20140521T000000  360000.0        3       2.50         1530
# 21609  6600060120  20150223T000000  400000.0        4       2.50         2310
# 21610  1523300141  20140623T000000  402101.0        2       0.75         1020
# 21611   291310100  20150116T000000  400000.0        3       2.50         1600
# 21612  1523300157  20141015T000000  325000.0        2       0.75         1020
#
# ...

# %%
houses.loc[good_view_houses & high_quality_houses, ['luxury_level']] = 'Luxury'

# %%
houses[good_view_houses & high_quality_houses]
# Out:
#                id             date      price bedrooms  bathrooms  \
# 9254   9208900037  20140919T000000  6885000.0        6       7.75
# 14556  2303900035  20140611T000000  2888000.0        5       6.25
# 19017  2303900100  20140911T000000  3800000.0        3       4.25
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9254          9890     31374     2.0           0     4  ...        8860
# 14556         8670     64033     2.0           0     4  ...        6120
# 19017         5510     35000     2.0           0     4  ...        4910
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 9254            1030      2001             0    98039  47.6305 -122.240
# 14556           2550      1965          2003    98177  47.7295 -122.372
# 19017            600      1997             0    98177  47.7296 -122.370
#
#        sqft_living15  sqft_lot15  luxury_level
# 9254            4540       42730        Luxury
# ...
